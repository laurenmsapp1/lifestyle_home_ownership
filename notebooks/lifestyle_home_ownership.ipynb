# %% [markdown]
# Combine the two CSV files from Kaggle to create a new data set.

# %%
import pandas as pd

# %%
household_df = pd.read_csv('household_data.csv')
sleep_df = pd.read_csv('sleep_health_and_lifestyle_dataset.csv')
